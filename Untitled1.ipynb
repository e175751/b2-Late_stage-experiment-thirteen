# %%
import matplotlib.pyplot as plt
import numpy as np
x=[]
y=[]
r=3.50

# %%
for init in np.arange(0,1,0.001):
    for j in range(0,201):
        if 1<=j:
            init_n = r*(1-init_n)*init_n
            if 150<=j:
                x.append(init)
                y.append(init_n)

# %%
plt.xlim(0,1)
plt.ylim(0,1)
plt.plot(x,y,".",markersize=1)
#plt.savefig("s_3.20.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[]
y=[]
r=3.86
for init in np.arange(0,1,0.001):
    init_n=init
    for i in range(0,201):
        if 150<=i:
            x.append(init)
            y.append(init_n)
        init_n = r*(1-init_n)*init_n
        
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel("X0")
plt.ylabel("150<=Xn+1<=200")
plt.plot(x,y,".",markersize=1)
plt.savefig("s_386.png")
